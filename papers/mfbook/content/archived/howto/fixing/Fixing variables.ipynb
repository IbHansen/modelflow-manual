# %% [markdown]
# # Fixing the value of variables
# Provided a model has been specified to allow this it is possible to fix the values of some endogenous variable. This can be
# useful in many situations. Also when a variable is fixed a matching add factor is calculated. This keeps the result unchanged
# when the fixing is lifted and the marginal properties of the model is preserved.

# %% [markdown]
# ## Import the model class
# This class incorporates most of the methods used to manage a model.

# %%
#This is code to manage dependencies if the notebook is executed in the google colab cloud service
if 'google.colab' in str(get_ipython()):
  import os
  os.system('apt -qqq install graphviz')
  os.system('pip -qqq install ModelFlowIb ipysheet  --no-dependencies ')
  incolab = True  
else:
  incolab = False

# %%
 # %load_ext autoreload
 # %autoreload 2

# %%
import pandas as pd
from modelclass import model 
import modelwidget as mw
model.widescreen()
model.scroll_off()
# Out:
#         <style>
#             div#notebook-container    { width: 95%; }
#             div#menubar-container     { width: 65%; }
#             div#maintoolbar-container { width: 99%; }
#         </style>

# %% [markdown]
# ## Load a pre-existing model, data and descriptions
# The file `pak.pcim` contains a dump of model equations, dataframe, simulation options and variable descriptions. The file was created separately.
#
# The modelload method returns an instance ```mpak``` of the ```model``` class, and a dataframe ```result``` that holds the baseline run.

# %%
mpak,result = model.modelload('../../models/pak.pcim',run=1,silent=1)
# Out:
# file read:  C:\mflow\modelflow-manual\papers\mfbook\content\models\pak.pcim

# %% [markdown]
# ## How to fix the values for variables
#
# The equation for a fixable variable should like this:
# >frml <z,exo> VAR  = (expression)*(1-VAR_D) + VAR_X * VAR_D
#
# Each endogenous variable which has an _D variable and _X variable can be fixed
#
# _D=1 means that the variable is to be fixed and
#
# _X holds the value to which it should be fixed
#
# In the pak model all stocastic equations are fixable.

# %% [markdown]
# ### .fix(dataframe,variable pattern, start,end) Returns a dataframe where variables matching pattern are fixed
#
# The code fixes the values for some variables by setting the _X variable to the current value, and _D variable to 1 in the timespan \[start,end].

# %%
var_to_be_fixed = 'PAKGGEXPCAPTCN PAKGGEXPGNFSCN PAKGGEXPOTHRCN PAKGGEXPTRNSCN'
fix_df = mpak.fix(result,var_to_be_fixed,2021,2100)

# %% [markdown]
# ## Now run the model with the new dataframe

# %%
_ = mpak(fix_df,silent=1,keep=f'Baseline') # _ is just a  name, the dataframe is not going to be used

# %%
alternative  =  fix_df.upd("<2023 2100> PAKGGREVCO2CER PAKGGREVCO2GER PAKGGREVCO2OER = 29")

# %%
_ = mpak(alternative,silent=1,keep=f'Tax = 29',alfa = 0.5)

# %%
with mpak.set_smpl(2020,2030):
    display(mpak['PAKNYGDPMKTPKN'])
# Out:
# Tab(children=(Tab(children=(HTML(value='<?xml version="1.0" encoding="utf-8" standalone="no"?>\n<!DOCTYPE svg …

# %% [markdown]
# ### .fix_inf() Show relevant variables for each fixed variables
# To make it short we only show the first 4 years

# %%
with mpak.set_smpl(2021,2024):
    mpak.fix_inf()
# Out:
# General government expenditure on capital expenditure (millions lcu)
#
# FRML <Z,EXO> PAKGGEXPCAPTCN = (0.3*PAKGGEXPCAPTCN(-1)+(1-0.3)*(0.37*(PAKGGREVTOTLCN-PAKGGEXPINTPCN(-0)))+393385.011*DURING_2013 + PAKGGEXPCAPTCN_A)* (1-PAKGGEXPCAPTCN_D)+ PAKGGEXPCAPTCN_X*PAKGGEXPCAPTCN_D  $
#
# FRML <CALC> PAKGGEXPCAPTCN_A = (PAKGGEXPCAPTCN) - (0.3*PAKGGEXPCAPTCN(-1)+(1-0.3)*(0.37*(PAKGGREVTOTLCN-PAKGGEXPINTPCN(-0)))+393385.011*DURING_2013)$
# <style type="text/css">
# #T_cfb1b thead tr:nth-child(1) th {
#   position: sticky;
#   background-color: white;
#   top: 0px;
#   z-index: 2;
# }
# #T_cfb1b thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: white;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_cfb1b tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: white;
#   left: 0px;
#   z-index: 1;
# }
# #T_cfb1b .pd-t {
#   visibility: hidden;
#   position: absolute;
#   z-index: 1;
#   border: 1px solid #000066;
#   background-color: white;
#   color: #000066;
#   font-size: 0.8em;
#   width: 100%transform;
#   padding: 0.6em;
#   border-radius: 0.5em;
# }
# #T_cfb1b #T_cfb1b_row0_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_cfb1b #T_cfb1b_row0_col0 .pd-t::after {
#   content: "General government expenditure on capital expenditure (millions lcu)";
# }
# #T_cfb1b #T_cfb1b_row0_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_cfb1b #T_cfb1b_row0_col1 .pd-t::after {
#   content: "Fix value:General government expenditure on capital expenditure (millions lcu)";
# }
# #T_cfb1b #T_cfb1b_row0_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_cfb1b #T_cfb1b_row0_col2 .pd-t::after {
#   content: "Fix dummy:General government expenditure on capital expenditure (millions lcu)";
# }
# #T_cfb1b #T_cfb1b_row0_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_cfb1b #T_cfb1b_row0_col3 .pd-t::after {
#   content: "Add factor:General government expenditure on capital expenditure (millions lcu)";
# }
# #T_cfb1b #T_cfb1b_row1_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_cfb1b #T_cfb1b_row1_col0 .pd-t::after {
#   content: "General government expenditure on capital expenditure (millions lcu)";
# }
# #T_cfb1b #T_cfb1b_row1_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_cfb1b #T_cfb1b_row1_col1 .pd-t::after {
#   content: "Fix value:General government expenditure on capital expenditure (millions lcu)";
# }
# #T_cfb1b #T_cfb1b_row1_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_cfb1b #T_cfb1b_row1_col2 .pd-t::after {
#   content: "Fix dummy:General government expenditure on capital expenditure (millions lcu)";
# }
# #T_cfb1b #T_cfb1b_row1_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_cfb1b #T_cfb1b_row1_col3 .pd-t::after {
#   content: "Add factor:General government expenditure on capital expenditure (millions lcu)";
# }
# #T_cfb1b #T_cfb1b_row2_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_cfb1b #T_cfb1b_row2_col0 .pd-t::after {
#   content: "General government expenditure on capital expenditure (millions lcu)";
# }
# #T_cfb1b #T_cfb1b_row2_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_cfb1b #T_cfb1b_row2_col1 .pd-t::after {
#   content: "Fix value:General government expenditure on capital expenditure (millions lcu)";
# }
# #T_cfb1b #T_cfb1b_row2_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_cfb1b #T_cfb1b_row2_col2 .pd-t::after {
#   content: "Fix dummy:General government expenditure on capital expenditure (millions lcu)";
# }
# #T_cfb1b #T_cfb1b_row2_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_cfb1b #T_cfb1b_row2_col3 .pd-t::after {
#   content: "Add factor:General government expenditure on capital expenditure (millions lcu)";
# }
# #T_cfb1b #T_cfb1b_row3_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_cfb1b #T_cfb1b_row3_col0 .pd-t::after {
#   content: "General government expenditure on capital expenditure (millions lcu)";
# }
# #T_cfb1b #T_cfb1b_row3_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_cfb1b #T_cfb1b_row3_col1 .pd-t::after {
#   content: "Fix value:General government expenditure on capital expenditure (millions lcu)";
# }
# #T_cfb1b #T_cfb1b_row3_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_cfb1b #T_cfb1b_row3_col2 .pd-t::after {
#   content: "Fix dummy:General government expenditure on capital expenditure (millions lcu)";
# }
# #T_cfb1b #T_cfb1b_row3_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_cfb1b #T_cfb1b_row3_col3 .pd-t::after {
#   content: "Add factor:General government expenditure on capital expenditure (millions lcu)";
# }
# </style>
# <table id="T_cfb1b" class="table">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cfb1b_level0_col0" class="col_heading level0 col0" >PAKGGEXPCAPTCN</th>
#       <th id="T_cfb1b_level0_col1" class="col_heading level0 col1" >PAKGGEXPCAPTCN_X</th>
#       <th id="T_cfb1b_level0_col2" class="col_heading level0 col2" >PAKGGEXPCAPTCN_D</th>
#       <th id="T_cfb1b_level0_col3" class="col_heading level0 col3" >PAKGGEXPCAPTCN_A</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cfb1b_level0_row0" class="row_heading level0 row0" >2021</th>
#       <td id="T_cfb1b_row0_col0" class="data row0 col0" >2974606.103547<span class="pd-t"></span></td>
#       <td id="T_cfb1b_row0_col1" class="data row0 col1" >2974606.103547<span class="pd-t"></span></td>
#       <td id="T_cfb1b_row0_col2" class="data row0 col2" > 1 <span class="pd-t"></span></td>
#       <td id="T_cfb1b_row0_col3" class="data row0 col3" >182969.551875<span class="pd-t"></span></td>
#     </tr>
#     <tr>
#       <th id="T_cfb1b_level0_row1" class="row_heading level0 row1" >2022</th>
#       <td id="T_cfb1b_row1_col0" class="data row1 col0" >3350772.739313<span class="pd-t"></span></td>
#       <td id="T_cfb1b_row1_col1" class="data row1 col1" >3350772.739313<span class="pd-t"></span></td>
#       <td id="T_cfb1b_row1_col2" class="data row1 col2" > 1 <span class="pd-t"></span></td>
#       <td id="T_cfb1b_row1_col3" class="data row1 col3" >155524.069095<span class="pd-t"></span></td>
#     </tr>
#     <tr>
#       <th id="T_cfb1b_level0_row2" class="row_heading level0 row2" >2023</th>
#       <td id="T_cfb1b_row2_col0" class="data row2 col0" >3753199.753576<span class="pd-t"></span></td>
#       <td id="T_cfb1b_row2_col1" class="data row2 col1" >3753199.753576<span class="pd-t"></span></td>
#       <td id="T_cfb1b_row2_col2" class="data row2 col2" > 1 <span class="pd-t"></span></td>
#       <td id="T_cfb1b_row2_col3" class="data row2 col3" >-103778.940212<span class="pd-t"></span></td>
#     </tr>
#     <tr>
#       <th id="T_cfb1b_level0_row3" class="row_heading level0 row3" >2024</th>
#       <td id="T_cfb1b_row3_col0" class="data row3 col0" >4183595.804971<span class="pd-t"></span></td>
#       <td id="T_cfb1b_row3_col1" class="data row3 col1" >4183595.804971<span class="pd-t"></span></td>
#       <td id="T_cfb1b_row3_col2" class="data row3 col2" > 1 <span class="pd-t"></span></td>
#       <td id="T_cfb1b_row3_col3" class="data row3 col3" >-132838.186771<span class="pd-t"></span></td>
#     </tr>
#   </tbody>
# </table>
# General government expenditure on goods and services (millions lcu)
#
# FRML <Z,EXO> PAKGGEXPGNFSCN = (0.3*PAKGGEXPGNFSCN(-1)+(1-0.3)*(0.80*(PAKGGREVTOTLCN-PAKGGEXPINTPCN(-0)))+505277.259999999*DURING_2012 + PAKGGEXPGNFSCN_A)* (1-PAKGGEXPGNFSCN_D)+ PAKGGEXPGNFSCN_X*PAKGGEXPGNFSCN_D  $
#
# FRML <CALC> PAKGGEXPGNFSCN_A = (PAKGGEXPGNFSCN) - (0.3*PAKGGEXPGNFSCN(-1)+(1-0.3)*(0.80*(PAKGGREVTOTLCN-PAKGGEXPINTPCN(-0)))+505277.259999999*DURING_2012)$
# <style type="text/css">
# #T_6248a thead tr:nth-child(1) th {
#   position: sticky;
#   background-color: white;
#   top: 0px;
#   z-index: 2;
# }
# #T_6248a thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: white;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_6248a tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: white;
#   left: 0px;
#   z-index: 1;
# }
# #T_6248a .pd-t {
#   visibility: hidden;
#   position: absolute;
#   z-index: 1;
#   border: 1px solid #000066;
#   background-color: white;
#   color: #000066;
#   font-size: 0.8em;
#   width: 100%transform;
#   padding: 0.6em;
#   border-radius: 0.5em;
# }
# #T_6248a #T_6248a_row0_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_6248a #T_6248a_row0_col0 .pd-t::after {
#   content: "General government expenditure on goods and services (millions lcu)";
# }
# #T_6248a #T_6248a_row0_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_6248a #T_6248a_row0_col1 .pd-t::after {
#   content: "Fix value:General government expenditure on goods and services (millions lcu)";
# }
# #T_6248a #T_6248a_row0_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_6248a #T_6248a_row0_col2 .pd-t::after {
#   content: "Fix dummy:General government expenditure on goods and services (millions lcu)";
# }
# #T_6248a #T_6248a_row0_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_6248a #T_6248a_row0_col3 .pd-t::after {
#   content: "Add factor:General government expenditure on goods and services (millions lcu)";
# }
# #T_6248a #T_6248a_row1_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_6248a #T_6248a_row1_col0 .pd-t::after {
#   content: "General government expenditure on goods and services (millions lcu)";
# }
# #T_6248a #T_6248a_row1_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_6248a #T_6248a_row1_col1 .pd-t::after {
#   content: "Fix value:General government expenditure on goods and services (millions lcu)";
# }
# #T_6248a #T_6248a_row1_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_6248a #T_6248a_row1_col2 .pd-t::after {
#   content: "Fix dummy:General government expenditure on goods and services (millions lcu)";
# }
# #T_6248a #T_6248a_row1_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_6248a #T_6248a_row1_col3 .pd-t::after {
#   content: "Add factor:General government expenditure on goods and services (millions lcu)";
# }
# #T_6248a #T_6248a_row2_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_6248a #T_6248a_row2_col0 .pd-t::after {
#   content: "General government expenditure on goods and services (millions lcu)";
# }
# #T_6248a #T_6248a_row2_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_6248a #T_6248a_row2_col1 .pd-t::after {
#   content: "Fix value:General government expenditure on goods and services (millions lcu)";
# }
# #T_6248a #T_6248a_row2_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_6248a #T_6248a_row2_col2 .pd-t::after {
#   content: "Fix dummy:General government expenditure on goods and services (millions lcu)";
# }
# #T_6248a #T_6248a_row2_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_6248a #T_6248a_row2_col3 .pd-t::after {
#   content: "Add factor:General government expenditure on goods and services (millions lcu)";
# }
# #T_6248a #T_6248a_row3_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_6248a #T_6248a_row3_col0 .pd-t::after {
#   content: "General government expenditure on goods and services (millions lcu)";
# }
# #T_6248a #T_6248a_row3_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_6248a #T_6248a_row3_col1 .pd-t::after {
#   content: "Fix value:General government expenditure on goods and services (millions lcu)";
# }
# #T_6248a #T_6248a_row3_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_6248a #T_6248a_row3_col2 .pd-t::after {
#   content: "Fix dummy:General government expenditure on goods and services (millions lcu)";
# }
# #T_6248a #T_6248a_row3_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_6248a #T_6248a_row3_col3 .pd-t::after {
#   content: "Add factor:General government expenditure on goods and services (millions lcu)";
# }
# </style>
# <table id="T_6248a" class="table">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6248a_level0_col0" class="col_heading level0 col0" >PAKGGEXPGNFSCN</th>
#       <th id="T_6248a_level0_col1" class="col_heading level0 col1" >PAKGGEXPGNFSCN_X</th>
#       <th id="T_6248a_level0_col2" class="col_heading level0 col2" >PAKGGEXPGNFSCN_D</th>
#       <th id="T_6248a_level0_col3" class="col_heading level0 col3" >PAKGGEXPGNFSCN_A</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6248a_level0_row0" class="row_heading level0 row0" >2021</th>
#       <td id="T_6248a_row0_col0" class="data row0 col0" >6273348.472013<span class="pd-t"></span></td>
#       <td id="T_6248a_row0_col1" class="data row0 col1" >6273348.472013<span class="pd-t"></span></td>
#       <td id="T_6248a_row0_col2" class="data row0 col2" > 1 <span class="pd-t"></span></td>
#       <td id="T_6248a_row0_col3" class="data row0 col3" >292080.034768<span class="pd-t"></span></td>
#     </tr>
#     <tr>
#       <th id="T_6248a_level0_row1" class="row_heading level0 row1" >2022</th>
#       <td id="T_6248a_row1_col0" class="data row1 col0" >7109444.007169<span class="pd-t"></span></td>
#       <td id="T_6248a_row1_col1" class="data row1 col1" >7109444.007169<span class="pd-t"></span></td>
#       <td id="T_6248a_row1_col2" class="data row1 col2" > 1 <span class="pd-t"></span></td>
#       <td id="T_6248a_row1_col3" class="data row1 col3" >248267.921448<span class="pd-t"></span></td>
#     </tr>
#     <tr>
#       <th id="T_6248a_level0_row2" class="row_heading level0 row2" >2023</th>
#       <td id="T_6248a_row2_col0" class="data row2 col0" >7999585.201438<span class="pd-t"></span></td>
#       <td id="T_6248a_row2_col1" class="data row2 col1" >7999585.201438<span class="pd-t"></span></td>
#       <td id="T_6248a_row2_col2" class="data row2 col2" > 1 <span class="pd-t"></span></td>
#       <td id="T_6248a_row2_col3" class="data row2 col3" >-299187.183403<span class="pd-t"></span></td>
#     </tr>
#     <tr>
#       <th id="T_6248a_level0_row3" class="row_heading level0 row3" >2024</th>
#       <td id="T_6248a_row3_col0" class="data row3 col0" >8947399.920655<span class="pd-t"></span></td>
#       <td id="T_6248a_row3_col1" class="data row3 col1" >8947399.920655<span class="pd-t"></span></td>
#       <td id="T_6248a_row3_col2" class="data row3 col2" > 1 <span class="pd-t"></span></td>
#       <td id="T_6248a_row3_col3" class="data row3 col3" >-350797.943926<span class="pd-t"></span></td>
#     </tr>
#   </tbody>
# </table>
# General government expenditures, other (includes transfers), (millions LCU)
#
# FRML <Z,EXO> PAKGGEXPOTHRCN = (PAKGGEXPOTHRCN_A*PAKNYGDPMKTPXN*PAKNYGDPPOTLKN+PAKNYGDPMKTPXN*PAKNYGDPPOTLKN* (-0.00369060695899124) ) * (1-PAKGGEXPOTHRCN_D)+ PAKGGEXPOTHRCN_X*PAKGGEXPOTHRCN_D  $
#
# FRML <CALC> PAKGGEXPOTHRCN_A = PAKGGEXPOTHRCN/(PAKNYGDPMKTPXN*PAKNYGDPPOTLKN)- ((-0.00369060695899124)) $
# <style type="text/css">
# #T_85de0 thead tr:nth-child(1) th {
#   position: sticky;
#   background-color: white;
#   top: 0px;
#   z-index: 2;
# }
# #T_85de0 thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: white;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_85de0 tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: white;
#   left: 0px;
#   z-index: 1;
# }
# #T_85de0 .pd-t {
#   visibility: hidden;
#   position: absolute;
#   z-index: 1;
#   border: 1px solid #000066;
#   background-color: white;
#   color: #000066;
#   font-size: 0.8em;
#   width: 100%transform;
#   padding: 0.6em;
#   border-radius: 0.5em;
# }
# #T_85de0 #T_85de0_row0_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_85de0 #T_85de0_row0_col0 .pd-t::after {
#   content: "General government expenditures, other (includes transfers), (millions LCU)";
# }
# #T_85de0 #T_85de0_row0_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_85de0 #T_85de0_row0_col1 .pd-t::after {
#   content: "Fix value:General government expenditures, other (includes transfers), (millions LCU)";
# }
# #T_85de0 #T_85de0_row0_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_85de0 #T_85de0_row0_col2 .pd-t::after {
#   content: "Fix dummy:General government expenditures, other (includes transfers), (millions LCU)";
# }
# #T_85de0 #T_85de0_row0_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_85de0 #T_85de0_row0_col3 .pd-t::after {
#   content: "Add factor:General government expenditures, other (includes transfers), (millions LCU)";
# }
# #T_85de0 #T_85de0_row1_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_85de0 #T_85de0_row1_col0 .pd-t::after {
#   content: "General government expenditures, other (includes transfers), (millions LCU)";
# }
# #T_85de0 #T_85de0_row1_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_85de0 #T_85de0_row1_col1 .pd-t::after {
#   content: "Fix value:General government expenditures, other (includes transfers), (millions LCU)";
# }
# #T_85de0 #T_85de0_row1_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_85de0 #T_85de0_row1_col2 .pd-t::after {
#   content: "Fix dummy:General government expenditures, other (includes transfers), (millions LCU)";
# }
# #T_85de0 #T_85de0_row1_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_85de0 #T_85de0_row1_col3 .pd-t::after {
#   content: "Add factor:General government expenditures, other (includes transfers), (millions LCU)";
# }
# #T_85de0 #T_85de0_row2_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_85de0 #T_85de0_row2_col0 .pd-t::after {
#   content: "General government expenditures, other (includes transfers), (millions LCU)";
# }
# #T_85de0 #T_85de0_row2_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_85de0 #T_85de0_row2_col1 .pd-t::after {
#   content: "Fix value:General government expenditures, other (includes transfers), (millions LCU)";
# }
# #T_85de0 #T_85de0_row2_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_85de0 #T_85de0_row2_col2 .pd-t::after {
#   content: "Fix dummy:General government expenditures, other (includes transfers), (millions LCU)";
# }
# #T_85de0 #T_85de0_row2_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_85de0 #T_85de0_row2_col3 .pd-t::after {
#   content: "Add factor:General government expenditures, other (includes transfers), (millions LCU)";
# }
# #T_85de0 #T_85de0_row3_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_85de0 #T_85de0_row3_col0 .pd-t::after {
#   content: "General government expenditures, other (includes transfers), (millions LCU)";
# }
# #T_85de0 #T_85de0_row3_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_85de0 #T_85de0_row3_col1 .pd-t::after {
#   content: "Fix value:General government expenditures, other (includes transfers), (millions LCU)";
# }
# #T_85de0 #T_85de0_row3_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_85de0 #T_85de0_row3_col2 .pd-t::after {
#   content: "Fix dummy:General government expenditures, other (includes transfers), (millions LCU)";
# }
# #T_85de0 #T_85de0_row3_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_85de0 #T_85de0_row3_col3 .pd-t::after {
#   content: "Add factor:General government expenditures, other (includes transfers), (millions LCU)";
# }
# </style>
# <table id="T_85de0" class="table">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_85de0_level0_col0" class="col_heading level0 col0" >PAKGGEXPOTHRCN</th>
#       <th id="T_85de0_level0_col1" class="col_heading level0 col1" >PAKGGEXPOTHRCN_X</th>
#       <th id="T_85de0_level0_col2" class="col_heading level0 col2" >PAKGGEXPOTHRCN_D</th>
#       <th id="T_85de0_level0_col3" class="col_heading level0 col3" >PAKGGEXPOTHRCN_A</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_85de0_level0_row0" class="row_heading level0 row0" >2021</th>
#       <td id="T_85de0_row0_col0" class="data row0 col0" >-157197.246534<span class="pd-t"></span></td>
#       <td id="T_85de0_row0_col1" class="data row0 col1" >-157197.246534<span class="pd-t"></span></td>
#       <td id="T_85de0_row0_col2" class="data row0 col2" > 1 <span class="pd-t"></span></td>
#       <td id="T_85de0_row0_col3" class="data row0 col3" >0.000630<span class="pd-t"></span></td>
#     </tr>
#     <tr>
#       <th id="T_85de0_level0_row1" class="row_heading level0 row1" >2022</th>
#       <td id="T_85de0_row1_col0" class="data row1 col0" >-182595.726020<span class="pd-t"></span></td>
#       <td id="T_85de0_row1_col1" class="data row1 col1" >-182595.726020<span class="pd-t"></span></td>
#       <td id="T_85de0_row1_col2" class="data row1 col2" > 1 <span class="pd-t"></span></td>
#       <td id="T_85de0_row1_col3" class="data row1 col3" >0.000535<span class="pd-t"></span></td>
#     </tr>
#     <tr>
#       <th id="T_85de0_level0_row2" class="row_heading level0 row2" >2023</th>
#       <td id="T_85de0_row2_col0" class="data row2 col0" >-209094.462145<span class="pd-t"></span></td>
#       <td id="T_85de0_row2_col1" class="data row2 col1" >-209094.462145<span class="pd-t"></span></td>
#       <td id="T_85de0_row2_col2" class="data row2 col2" > 1 <span class="pd-t"></span></td>
#       <td id="T_85de0_row2_col3" class="data row2 col3" >0.000495<span class="pd-t"></span></td>
#     </tr>
#     <tr>
#       <th id="T_85de0_level0_row3" class="row_heading level0 row3" >2024</th>
#       <td id="T_85de0_row3_col0" class="data row3 col0" >-236487.252829<span class="pd-t"></span></td>
#       <td id="T_85de0_row3_col1" class="data row3 col1" >-236487.252829<span class="pd-t"></span></td>
#       <td id="T_85de0_row3_col2" class="data row3 col2" > 1 <span class="pd-t"></span></td>
#       <td id="T_85de0_row3_col3" class="data row3 col3" >0.000419<span class="pd-t"></span></td>
#     </tr>
#   </tbody>
# </table>
# Current Transfers
#
# FRML <Z,EXO> PAKGGEXPTRNSCN = (0.91020884318931*PAKGGEXPTRNSCN(-1)+(1-0.91020884318931)*(0.06*(PAKGGREVTOTLCN-PAKGGEXPINTPCN(-0))) + PAKGGEXPTRNSCN_A)* (1-PAKGGEXPTRNSCN_D)+ PAKGGEXPTRNSCN_X*PAKGGEXPTRNSCN_D  $
#
# FRML <CALC> PAKGGEXPTRNSCN_A = (PAKGGEXPTRNSCN) - (0.91020884318931*PAKGGEXPTRNSCN(-1)+(1-0.91020884318931)*(0.06*(PAKGGREVTOTLCN-PAKGGEXPINTPCN(-0))))$
# <style type="text/css">
# #T_b4823 thead tr:nth-child(1) th {
#   position: sticky;
#   background-color: white;
#   top: 0px;
#   z-index: 2;
# }
# #T_b4823 thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: white;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_b4823 tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: white;
#   left: 0px;
#   z-index: 1;
# }
# #T_b4823 .pd-t {
#   visibility: hidden;
#   position: absolute;
#   z-index: 1;
#   border: 1px solid #000066;
#   background-color: white;
#   color: #000066;
#   font-size: 0.8em;
#   width: 100%transform;
#   padding: 0.6em;
#   border-radius: 0.5em;
# }
# #T_b4823 #T_b4823_row0_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_b4823 #T_b4823_row0_col0 .pd-t::after {
#   content: "Current Transfers";
# }
# #T_b4823 #T_b4823_row0_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_b4823 #T_b4823_row0_col1 .pd-t::after {
#   content: "Fix value:Current Transfers";
# }
# #T_b4823 #T_b4823_row0_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_b4823 #T_b4823_row0_col2 .pd-t::after {
#   content: "Fix dummy:Current Transfers";
# }
# #T_b4823 #T_b4823_row0_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_b4823 #T_b4823_row0_col3 .pd-t::after {
#   content: "Add factor:Current Transfers";
# }
# #T_b4823 #T_b4823_row1_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_b4823 #T_b4823_row1_col0 .pd-t::after {
#   content: "Current Transfers";
# }
# #T_b4823 #T_b4823_row1_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_b4823 #T_b4823_row1_col1 .pd-t::after {
#   content: "Fix value:Current Transfers";
# }
# #T_b4823 #T_b4823_row1_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_b4823 #T_b4823_row1_col2 .pd-t::after {
#   content: "Fix dummy:Current Transfers";
# }
# #T_b4823 #T_b4823_row1_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_b4823 #T_b4823_row1_col3 .pd-t::after {
#   content: "Add factor:Current Transfers";
# }
# #T_b4823 #T_b4823_row2_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_b4823 #T_b4823_row2_col0 .pd-t::after {
#   content: "Current Transfers";
# }
# #T_b4823 #T_b4823_row2_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_b4823 #T_b4823_row2_col1 .pd-t::after {
#   content: "Fix value:Current Transfers";
# }
# #T_b4823 #T_b4823_row2_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_b4823 #T_b4823_row2_col2 .pd-t::after {
#   content: "Fix dummy:Current Transfers";
# }
# #T_b4823 #T_b4823_row2_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_b4823 #T_b4823_row2_col3 .pd-t::after {
#   content: "Add factor:Current Transfers";
# }
# #T_b4823 #T_b4823_row3_col0:hover .pd-t {
#   visibility: visible;
# }
# #T_b4823 #T_b4823_row3_col0 .pd-t::after {
#   content: "Current Transfers";
# }
# #T_b4823 #T_b4823_row3_col1:hover .pd-t {
#   visibility: visible;
# }
# #T_b4823 #T_b4823_row3_col1 .pd-t::after {
#   content: "Fix value:Current Transfers";
# }
# #T_b4823 #T_b4823_row3_col2:hover .pd-t {
#   visibility: visible;
# }
# #T_b4823 #T_b4823_row3_col2 .pd-t::after {
#   content: "Fix dummy:Current Transfers";
# }
# #T_b4823 #T_b4823_row3_col3:hover .pd-t {
#   visibility: visible;
# }
# #T_b4823 #T_b4823_row3_col3 .pd-t::after {
#   content: "Add factor:Current Transfers";
# }
# </style>
# <table id="T_b4823" class="table">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b4823_level0_col0" class="col_heading level0 col0" >PAKGGEXPTRNSCN</th>
#       <th id="T_b4823_level0_col1" class="col_heading level0 col1" >PAKGGEXPTRNSCN_X</th>
#       <th id="T_b4823_level0_col2" class="col_heading level0 col2" >PAKGGEXPTRNSCN_D</th>
#       <th id="T_b4823_level0_col3" class="col_heading level0 col3" >PAKGGEXPTRNSCN_A</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b4823_level0_row0" class="row_heading level0 row0" >2021</th>
#       <td id="T_b4823_row0_col0" class="data row0 col0" >515359.573986<span class="pd-t"></span></td>
#       <td id="T_b4823_row0_col1" class="data row0 col1" >515359.573986<span class="pd-t"></span></td>
#       <td id="T_b4823_row0_col2" class="data row0 col2" > 1 <span class="pd-t"></span></td>
#       <td id="T_b4823_row0_col3" class="data row0 col3" >42678.845355<span class="pd-t"></span></td>
#     </tr>
#     <tr>
#       <th id="T_b4823_level0_row1" class="row_heading level0 row1" >2022</th>
#       <td id="T_b4823_row1_col0" class="data row1 col0" >553263.885067<span class="pd-t"></span></td>
#       <td id="T_b4823_row1_col1" class="data row1 col1" >553263.885067<span class="pd-t"></span></td>
#       <td id="T_b4823_row1_col2" class="data row1 col2" > 1 <span class="pd-t"></span></td>
#       <td id="T_b4823_row1_col3" class="data row1 col3" >36277.017735<span class="pd-t"></span></td>
#     </tr>
#     <tr>
#       <th id="T_b4823_level0_row2" class="row_heading level0 row2" >2023</th>
#       <td id="T_b4823_row2_col0" class="data row2 col0" >588831.934214<span class="pd-t"></span></td>
#       <td id="T_b4823_row2_col1" class="data row2 col1" >588831.934214<span class="pd-t"></span></td>
#       <td id="T_b4823_row2_col2" class="data row2 col2" > 1 <span class="pd-t"></span></td>
#       <td id="T_b4823_row2_col3" class="data row2 col3" >25926.952119<span class="pd-t"></span></td>
#     </tr>
#     <tr>
#       <th id="T_b4823_level0_row3" class="row_heading level0 row3" >2024</th>
#       <td id="T_b4823_row3_col0" class="data row3 col0" >623434.853192<span class="pd-t"></span></td>
#       <td id="T_b4823_row3_col1" class="data row3 col1" >623434.853192<span class="pd-t"></span></td>
#       <td id="T_b4823_row3_col2" class="data row3 col2" > 1 <span class="pd-t"></span></td>
#       <td id="T_b4823_row3_col3" class="data row3 col3" >21109.640260<span class="pd-t"></span></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### The result match the result before exogenizing, as it should
# Numbers below show the difference in pct betwen the solution whitout and with fixing
#
# The difference is small and OK

# %%
with mpak.keepswitch(True):
    mpak.keep_plot('PAKNYGDPMKTPKN',diffpct=1,dec=7)

# %% [markdown]
# ## Dump the model and solution for later use

# %%
mpak.modeldump('../../models/pak_exogenized.pcim')

# %% [markdown]
# ## More advanced information
# The model instance (here mpak) maintain properties related to the fixing of values.

# %% [markdown]
# ### List of potential and actual fixed variables
# The model instance (here mpak) maintain properties related to the fixing of values.
#
# |Variable type|Variable name suffix|Lists for all fixable variables|List of fixed variables|
# |:--|:--|:--|:--|
# Endogenous|  |.fix_endo|.fix_endo_fixed
# Dummy|_D|.fix_dummy|.fix_dummy_fixed
# Fixed value|_X|.fix_value|.fix_value_fixed
# Add factor|_A|.fix_add_factor|.fix_add_factor_fixed

# %% [markdown]
# #### LIst of all fixable variables for this model

# %%
all_fix_var =[vars for vars in zip(mpak.fix_dummy,mpak.fix_value,mpak.fix_add_factor)]
fix_names = pd.DataFrame(all_fix_var,columns=['Dummy','Fixed value','Add factor'],index=mpak.fix_endo)
mw.htmlwidget_df(mpak,fix_names).show
# Out:
# HTML(value='<style type="text/css">\n#T_cf167 thead tr:nth-child(1) th {\n  position: sticky;\n  background-co…

# %% [markdown]
# :::{note}
# **Dataframes with strings and zip**
#
# Pandas dataframes are very versatile. Here the dataframe is filled not with scalars but with strings.
#
# Also the zip function is used to combine lists. [More here](https://docs.python.org/3/library/functions.html#zip)
# :::

# %% [markdown]
# #### List of fixed variables

# %%
fixed_fix_var =[vars for vars in 
                 zip(mpak.fix_dummy_fixed,mpak.fix_value_fixed,mpak.fix_add_factor_fixed)]
fixed_names = pd.DataFrame(fixed_fix_var,columns=['Dummy','Fixed value','Add factor'],index=mpak.fix_endo_fixed)
mw.htmlwidget_df(mpak,fixed_names).show
# Out:
# HTML(value='<style type="text/css">\n#T_e648b_ thead tr:nth-child(1) th {\n  position: sticky;\n  background-c…

# %% [markdown]
# #### Is there a model (.calc_add_factor_model) available  to calculate the add factors corresponding to the fixed values

# %%
mpak.split_calc_add_factor
# Out:
# True

# %% [markdown]
# #### Show the equations for the .calc_add_factor_model
# Here only 3 are displayed. Delete the [:3] and all equations will be displayed.

# %%
mpak.calc_add_factor_model.equations.split('$')[:3]
# Out:
# ['FRML <CALC> PAKBMFSTOTHRCD_A = -PAKBMFSTOTHRCD/PAKNYGDPMKTPCD+ ((-0.0106244247103773)) ',
#  ' FRML <CALC> PAKBMFSTREMTCD_A = -PAKBMFSTREMTCD/PAKNYGDPMKTPCD+ ((5.83179728399106E-05)) ',
#  ' FRML <CALC> PAKBMGSRGNFSCD_A = -100*PAKBMGSRGNFSCD/PAKBMGSRGNFSCD(-1)+ (((100 * ( (PAKNEIMPGNFSCD) / (PAKNEIMPGNFSCD(-1)) -1)) +0.16331992292838*DUMH)) +100']
